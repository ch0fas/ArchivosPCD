# %% [markdown]
# <style>
# #title {
#     text-align: center;
#     font-family: Helvetica, Sans-serif;
# }
# #assign_name {
#     text-align: center;
#     font-size: 30px;
#     font-weight: 200
# }
# #info {
#     text-aling: left;
#     font-size: 20px;
#     font-weight: 200
# }
#
# </style>
#
# <h1 id='title'>Actividad de Clase 1</h1> <style>
# #title {
#     text-align: center;
#     font-family: Helvetica, Sans-serif;
# }
# #assign_name {
#     text-align: center;
#     font-size: 30px;
#     font-weight: 200
# }
# #info {
#     text-aling: left;
#     font-size: 20px;
#     font-weight: 200
# }
#
# </style>
#
# <h1 id='title'>Actividad de Clase 1</h1>
# <p id='assign_name'>MovieLens</p>
# <p id='info'>Por Sofía Maldonado García</p>
# <p id='info'>Curso: Proyecto de Ciencia de Datos</p>
# <p id='info'>Profesor: Cristian Zapata</p>
#
# ***
# <p id='assign_name'>MovieLens</p>
# <p id='info'>Por Sofía Maldonado García</p>
# <p id='info'>Curso: Proyecto de Ciencia de Datos</p>
# <p id='info'>Profesor: Cristian Zapata</p>
#
# ***

# %%
# Imports

import pandas as pd

# %%
# Importando datos como CSV

dflinks = pd.read_csv("data/links.csv")
dfmovies = pd.read_csv("data/movies.csv")
dfratings = pd.read_csv("data/ratings.csv")
dftags = pd.read_csv("data/tags.csv")

df = pd.merge(dflinks, dfmovies, how="left", on="movieId")
df = pd.merge(df, dfratings, how="left", on="movieId")
df = pd.merge(df, dftags, how="left", on="movieId")
df
# Out:
#         movieId   imdbId    tmdbId                                      title  \
# 0             1   114709     862.0                           Toy Story (1995)
# 1             1   114709     862.0                           Toy Story (1995)
# 2             1   114709     862.0                           Toy Story (1995)
# 3             1   114709     862.0                           Toy Story (1995)
# 4             1   114709     862.0                           Toy Story (1995)
# ...         ...      ...       ...                                        ...
# 285778   193581  5476944  432131.0  Black Butler: Book of the Atlantic (2017)
# 285779   193583  5914996  445030.0               No Game No Life: Zero (2017)
# 285780   193585  6397426  479308.0                               Flint (2017)
# 285781   193587  8391976  483455.0        Bungo Stray Dogs: Dead Apple (2018)
# 285782   193609   101726   37891.0        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       1.0     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy       1.0     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy       5.0     4.0
# 4       Adventure|Animation|Children|Comedy|Fantasy       5.0     4.0
# ...                                             ...       ...     ...
# 285778              Action|Animation|Comedy|Fantasy     184.0     4.0
# 285779                     Animation|Comedy|Fantasy     184.0     3.5
# 285780                                        Drama     184.0     3.5
# 285781                             Action|Animation     184.0     3.5
# 285782                                       Comedy     331.0     4.0
#
#          timestamp_x  userId_y    tag   timestamp_y
# 0       9.649827e+08     336.0  pixar  1.139046e+09
# 1       9.649827e+08     474.0  pixar  1.137207e+09
# 2       9.649827e+08     567.0    fun  1.525286e+09
# 3       8.474350e+08     336.0  pixar  1.139046e+09
# 4       8.474350e+08     474.0  pixar  1.137207e+09
# ...              ...       ...    ...           ...
# 285778  1.537109e+09       NaN    NaN           NaN
# 285779  1.537110e+09       NaN    NaN           NaN
# 285780  1.537110e+09       NaN    NaN           NaN
# 285781  1.537110e+09       NaN    NaN           NaN
# 285782  1.537158e+09       NaN    NaN           NaN
#
# [285783 rows x 11 columns]

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#              movieId        imdbId         tmdbId       userId_x  \
# count  285783.000000  2.857830e+05  285770.000000  285762.000000
# mean    14927.663741  2.956050e+05   12797.315320     313.894279
# std     31402.673519  5.150156e+05   43479.255523     179.451387
# min         1.000000  4.170000e+02       2.000000       1.000000
# 25%       296.000000  1.098300e+05     489.000000     160.000000
# 50%      1721.000000  1.125730e+05     680.000000     314.000000
# 75%      5673.000000  2.415270e+05    8963.000000     465.000000
# max    193609.000000  8.391976e+06  525662.000000     610.000000
#
#               rating   timestamp_x       userId_y   timestamp_y
# count  285762.000000  2.857620e+05  233234.000000  2.332340e+05
# mean        3.841270  1.214707e+09     470.681354  1.384754e+09
# std         1.020798  2.233730e+08     153.324249  1.534705e+08
# min         0.500000  8.281246e+08       2.000000  1.137179e+09
# 25%         3.000000  1.019133e+09     424.000000  1.242494e+09
# 50%         4.000000  1.211377e+09     477.000000  1.457901e+09
# 75%         4.500000  1.445346e+09     599.000000  1.498457e+09
# max         5.000000  1.537799e+09     610.000000  1.537099e+09

# %%
# Cuáles fueron las películas mejor rankeadas?

x = df.groupby(by="title", sort=False).sum()
x.sort_values("rating", ascending=False)
# Out:
#                                                      movieId      imdbId  \
# title
# Pulp Fiction (1994)                                 16447832  6163047104
# Fight Club (1999)                                   34833348  1618920756
# Star Wars: Episode IV - A New Hope (1977)            1696760   500929234
# Léon: The Professional (a.k.a. The Professional...   1363915   513972515
# Eternal Sunshine of the Spotless Mind (2004)        32785894  1505509902
# ...                                                      ...         ...
# For All Mankind (1989)                                  3338       97372
# In the Realms of the Unreal (2004)                     92676     1170369
# Chalet Girl (2011)                                     85565     1487118
# Innocents, The (1961)                                   1076       55018
# This Gun for Hire (1942)                                8765       35432
#
#                                                         tmdbId  \
# title
# Pulp Fiction (1994)                                 37785560.0
# Fight Club (1999)                                    6474600.0
# Star Wars: Episode IV - A New Hope (1977)              71786.0
# Léon: The Professional (a.k.a. The Professional...    470155.0
# Eternal Sunshine of the Spotless Mind (2004)          169252.0
# ...                                                        ...
# For All Mankind (1989)                                 20423.0
# In the Realms of the Unreal (2004)                      5559.0
# Chalet Girl (2011)                                     58232.0
# Innocents, The (1961)                                  16372.0
# This Gun for Hire (1942)                               16703.0
#
#                                                                                                genres  \
# title
# Pulp Fiction (1994)                                 Comedy|Crime|Drama|ThrillerComedy|Crime|Drama|...
# Fight Club (1999)                                   Action|Crime|Drama|ThrillerAction|Crime|Drama|...
# Star Wars: Episode IV - A New Hope (1977)           Action|Adventure|Sci-FiAction|Adventure|Sci-Fi...
# Léon: The Professional (a.k.a. The Professional...  Action|Crime|Drama|ThrillerAction|Crime|Drama|...
# Eternal Sunshine of the Spotless Mind (2004)        Drama|Romance|Sci-FiDrama|Romance|Sci-FiDrama|...
# ...                                                                                               ...
# For All Mankind (1989)                                                                    Documentary
# In the Realms of the Unreal (2004)                  Animation|DocumentaryAnimation|DocumentaryAnim...
# Chalet Girl (2011)                                                                     Comedy|Romance
# Innocents, The (1961)                                                           Drama|Horror|Thriller
# This Gun for Hire (1942)                                                     Crime|Film-Noir|Thriller
#
#                                                       userId_x    rating  \
# title
# Pulp Fiction (1994)                                 16402401.0  233218.5
# Fight Club (1999)                                    3765798.0   50301.0
# Star Wars: Episode IV - A New Hope (1977)            1988584.0   27612.0
# Léon: The Professional (a.k.a. The Professional...   1413335.0   18707.5
# Eternal Sunshine of the Spotless Mind (2004)         1440342.0   18530.0
# ...                                                        ...       ...
# For All Mankind (1989)                                     0.0       0.0
# In the Realms of the Unreal (2004)                         0.0       0.0
# Chalet Girl (2011)                                         0.0       0.0
# Innocents, The (1961)                                      0.0       0.0
# This Gun for Hire (1942)                                   0.0       0.0
#
#                                                      timestamp_x    userId_y  \
# title
# Pulp Fiction (1994)                                 6.320598e+13  32574542.0
# Fight Club (1999)                                   1.524233e+13   6835826.0
# Star Wars: Episode IV - A New Hope (1977)           7.761248e+12   1519052.0
# Léon: The Professional (a.k.a. The Professional...  5.491900e+12   2656542.0
# Eternal Sunshine of the Spotless Mind (2004)        5.824436e+12   2288570.0
# ...                                                          ...         ...
# For All Mankind (1989)                              0.000000e+00       474.0
# In the Realms of the Unreal (2004)                  0.000000e+00       954.0
# Chalet Girl (2011)                                  0.000000e+00       543.0
# Innocents, The (1961)                               0.000000e+00       474.0
# This Gun for Hire (1942)                            0.000000e+00       474.0
#
#                                                                                                   tag  \
# title
# Pulp Fiction (1994)                                 good dialoguegreat soundtracknon-linearcult fi...
# Fight Club (1999)                                   dark comedypsychologythought-provokingtwist en...
# Star Wars: Episode IV - A New Hope (1977)           classicspace actionactionsci-fiEPICgreat sound...
# Léon: The Professional (a.k.a. The Professional...  assassinJean Renohit menActionassassinassassin...
# Eternal Sunshine of the Spotless Mind (2004)        alternate realitymemorythought-provokingjim ca...
# ...                                                                                               ...
# For All Mankind (1989)                                                               In Netflix queue
# In the Realms of the Unreal (2004)                                   AnimationDocumentaryHenry Darger
# Chalet Girl (2011)                                                                             Comedy
# Innocents, The (1961)                                                                       governess
# This Gun for Hire (1942)                                                             In Netflix queue
#
#                                                      timestamp_y
# title
# Pulp Fiction (1994)                                 8.304271e+13
# Fight Club (1999)                                   1.749694e+13
# Star Wars: Episode IV - A New Hope (1977)           9.241349e+12
# Léon: The Professional (a.k.a. The Professional...  6.845016e+12
# Eternal Sunshine of the Spotless Mind (2004)        6.518901e+12
# ...                                                          ...
# For All Mankind (1989)                              1.137202e+09
# In the Realms of the Unreal (2004)                  3.720476e+09
# Chalet Girl (2011)                                  1.377022e+09
# Innocents, The (1961)                               1.137521e+09
# This Gun for Hire (1942)                            1.137180e+09
#
# [9737 rows x 10 columns]
